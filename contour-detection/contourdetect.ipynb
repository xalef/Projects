# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
image = cv2.imread('partsTest-1.png')
cv2.imshow('Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Resize image (scale percentage 60)
scale = 60
newWidth = int(image.shape[1] * scale / 100)
newHeight = int(image.shape[0] * scale / 100)
newDimension = (newWidth, newHeight)
resizedImage = cv2.resize(image, newDimension, interpolation = cv2.INTER_AREA)
cv2.imshow('Image', resizedImage)
cv2.waitKey(0)
cv2.destroyAllWindows()
#save the resized image
cv2.imwrite('resizedParts.png', resizedImage, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %%
#Convert to grayscale
grayImage = cv2.cvtColor(resizedImage, cv2.COLOR_BGR2GRAY)
cv2.imshow('Image', grayImage)
cv2.waitKey(0)
cv2.destroyAllWindows()
#save the grayscale image
cv2.imwrite('grayParts.png', grayImage, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %%
#Thresholding
estimatedThreshold, thresholdImage = cv2.threshold(grayImage, 90, 255, cv2.THRESH_BINARY)
cv2.imshow('Image', thresholdImage)
cv2.waitKey(0)
cv2.destroyAllWindows()
#save the threshold image
cv2.imwrite('thresholdParts.png', thresholdImage, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %%
#Plot histogram of threshold and grey image
plt.figure(figsize=(14, 12))
plt.subplot(2,2,1), plt.imshow(grayImage, 'gray'), plt.title('Grayscale Image')
plt.subplot(2,2,2), plt.hist(grayImage.ravel(), 256), plt.title('Histogram of Grayscale Image')
plt.subplot(2,2,3), plt.imshow(thresholdImage, 'gray'), plt.title('Threshold Image')
plt.subplot(2,2,4), plt.hist(thresholdImage.ravel(), 256), plt.title('Histogram of Threshold Image')
plt.show()

# %%
#Improve thresholding 
estimatedThreshold, thresholdImage = cv2.threshold(grayImage, 50, 255, cv2.THRESH_BINARY|cv2.THRESH_OTSU)
cv2.imshow('Image', thresholdImage)
cv2.waitKey(0)
cv2.destroyAllWindows()
#save the threshold image
cv2.imwrite('thresholdParts.png', thresholdImage, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %%
#Determine contours and filter them
contours, hierarchy = cv2.findContours(thresholdImage, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)

#make a copy of the resized image
resizedImageCopy = np.copy(resizedImage)

for i,c in enumerate(contours):
    areaContour = cv2.contourArea(c)
    if areaContour < 1000 or 100000<areaContour:
        continue
    cv2.drawContours(resizedImageCopy, contours, i, (255,10,255), 4)

# %%
#Display the original image with contours
cv2.imshow('Image', resizedImageCopy)
cv2.waitKey(0)
cv2.destroyAllWindows()
#save the image with contours
cv2.imwrite('contoursParts.png', resizedImageCopy, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %% [markdown]
# MICROSCOPE

# %%
#Apply the same process the the image named "Image160.jpg"
image = cv2.imread('Image160.jpg')
cv2.imshow('Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Resize image (scale percentage 60)
scale = 50
newWidth = int(image.shape[1] * scale / 100)
newHeight = int(image.shape[0] * scale / 100)
newDimension = (newWidth, newHeight)
resizedImage = cv2.resize(image, newDimension, interpolation = cv2.INTER_AREA)
cv2.imshow('Image', resizedImage)
cv2.waitKey(0)
cv2.destroyAllWindows()
#save the resized image
cv2.imwrite('resizedImage160.png', resizedImage, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %%
#Convert to grayscale
grayImage = cv2.cvtColor(resizedImage, cv2.COLOR_BGR2GRAY)
cv2.imshow('Image', grayImage)
cv2.waitKey(0)
cv2.destroyAllWindows()
#save the grayscale image
cv2.imwrite('grayImage160.png', grayImage, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %%
#Thresholding
estimatedThreshold, thresholdImage = cv2.threshold(grayImage, 100, 255, cv2.THRESH_BINARY)
cv2.imshow('Image', thresholdImage)
cv2.waitKey(0)
cv2.destroyAllWindows()
#save the threshold image
cv2.imwrite('thresholdImage160.png', thresholdImage, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %%
#Determine contours and filter them
contours, hierarchy = cv2.findContours(thresholdImage, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)

#make a copy of the resized image
resizedImageCopy = np.copy(resizedImage)

for i,c in enumerate(contours):
    areaContour = cv2.contourArea(c)
     # Filter contours based on area
    if areaContour < 1:
        continue
    cv2.drawContours(resizedImageCopy, contours, i, (255, 10, 255), 1)

# %%
#Display the original image with contours
cv2.imshow('Image', resizedImageCopy)
cv2.waitKey(0)
cv2.destroyAllWindows()
#save the image with contours
cv2.imwrite('contoursImage160.png', resizedImageCopy, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %% [markdown]
# ANOTHER IMAGE

# %%
#Do the same thing for the image named "Image164.jpg"
image = cv2.imread('Image164.jpg')
cv2.imshow('Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Resize image (scale percentage 60)
scale = 50
newWidth = int(image.shape[1] * scale / 100)
newHeight = int(image.shape[0] * scale / 100)
newDimension = (newWidth, newHeight)
resizedImage = cv2.resize(image, newDimension, interpolation = cv2.INTER_AREA)
cv2.imshow('Image', resizedImage)
cv2.waitKey(0)
cv2.destroyAllWindows()
#save the resized image
cv2.imwrite('resizedImage164.png', resizedImage, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %%
#Convert to grayscale
grayImage = cv2.cvtColor(resizedImage, cv2.COLOR_BGR2GRAY)
cv2.imshow('Image', grayImage)
cv2.waitKey(0)
cv2.destroyAllWindows()
#save the grayscale image
cv2.imwrite('grayImage164.png', grayImage, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %%
#Thresholding
estimatedThreshold, thresholdImage = cv2.threshold(grayImage, 100, 255, cv2.THRESH_BINARY)
cv2.imshow('Image', thresholdImage)
cv2.waitKey(0)
cv2.destroyAllWindows()
#save the threshold image
cv2.imwrite('thresholdImage164.png', thresholdImage, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %%
#Determine contours and filter them
contours, hierarchy = cv2.findContours(thresholdImage, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)

#make a copy of the resized image
resizedImageCopy = np.copy(resizedImage)

for i,c in enumerate(contours):
    areaContour = cv2.contourArea(c)
     # Filter contours based on area
    if areaContour < 1:
        continue
    cv2.drawContours(resizedImageCopy, contours, i, (255, 10, 255), 1)

# %%
#Display the original image with contours
cv2.imshow('Image', resizedImageCopy)
cv2.waitKey(0)
cv2.destroyAllWindows()
#save the image with contours
cv2.imwrite('contoursImage164.png', resizedImageCopy, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True
